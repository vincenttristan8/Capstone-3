# %% [markdown]
# # *SAUDI ARABIA USED CARS*
# [Sumber Data Saudi Arabia Used Cars](https://www.kaggle.com/datasets/turkibintalib/saudi-arabia-used-cars-dataset)

# %% [markdown]
# # Context
# Di pasar otomotif Arab Saudi yang berkembang pesat, harga mobil bekas menjadi hal yang penting bagi pembeli dan penjual dalam mencari kejelasan dan kepercayaan dalam transaksi. Namun, menentukan harga mobil bekas seringkali merupakan tantangan kompleks karena melibatkan sejumlah variabel seperti wilayah, jenis mobil serta spesifikasi mobil. Untuk mengatasi kompleksitas ini, penerapan model machine learning dapat memberikan solusi yang efektif. Dengan mengumpulkan dan menganalisis data yang relevan, model machine learning dapat dikembangkan untuk memprediksi harga mobil bekas dengan tingkat akurasi yang lebih tinggi, memberikan manfaat besar bagi pelaku pasar otomotif dengan memberikan perkiraan/ prediksi harga yang lebih tepat dan mengurangi ketidakpastian dalam proses jual-beli mobil bekas di Arab Saudi. Model machine learning ini diperuntukan kepada pelaku pasar otomotif seperti showroom, sales, marketing, dll.

# %% [markdown]
# # Problem Statement
# Tantangan utama adalah ketidakpastian dalam menetapkan harga yang wajar, yang dapat mengakibatkan overpricing (penawaran harga terlalu tinggi) dan underpricing (penawaran harga terlalu rendah). Overpricing dalam penjualan mobil bekas dapat mengakibatkan penurunan minat pembeli dan kerugian finansial bagi penjual, sementara underpricing dapat menyebabkan kerugian finansial bagi penjual dan ketidakpuasan pembeli karena nilai jual kembali yang rendah. Dengan beragamnya atribut mobil, seperti jenis, lokasi, produsen, transmisi, opsi tambahan, tahun pembuatan, ukuran mesin, dan jarak tempuh, menentukan nilai jual kembali yang tepat menjadi rumit.

# %% [markdown]
# # Goals
# Tujuan utama membuat model machine learning ini adalah mengembangkan model machine learning yang mampu secara akurat memprediksi harga mobil bekas di Arab Saudi berdasarkan berbagai atribut, dengan fokus utama pada menghindari overpricing dan underpricing. Model ini diharapkan dapat memberikan nilai yang realistis dan transparan, memberikan manfaat baik bagi penjual yang ingin mendapatkan nilai maksimal dari penjualan mereka maupun bagi pembeli yang mencari kesepakatan yang adil. Dengan berhasil mencapai tujuan ini, proyek ini akan membantu menciptakan stabilitas dan kepercayaan dalam pasar otomotif, memberikan keuntungan bagi semua pemangku kepentingan yang terlibat dalam proses jual-beli mobil bekas di Arab Saudi.

# %% [markdown]
# # Analytic Approach
# Pendekatan analitik dalam proyek ini akan dimulai dengan eksplorasi dan pembersihan data, termasuk penanganan data yang hilang atau tidak lengkap, serta konversi variabel kategorikal menjadi format yang dapat diolah oleh model machine learning. Setelah itu, akan dilakukan analisis eksploratif untuk memahami hubungan antar atribut dan mendeteksi pola-pola penting dalam data. Pemilihan fitur yang relevan dan pelatihan model machine learning, seperti regresi linier atau model lainnya.

# %% [markdown]
# # Metric Evaluation
# Dalam evaluasi model machine learning untuk memprediksi harga mobil bekas, beberapa metrik kinerja digunakan untuk memberikan pemahaman tentang seberapa baik model tersebut bekerja. Mean Absolute Error (MAE) metrik yang mengukur rata-rata dari selisih absolut antara nilai sebenarnya dan nilai perkiraan, digunakan untuk mengukur kesalahan prediksi secara keseluruhan, sementara Mean Squared Error (MSE) metrik yang mengukur rata-rata dari selisih absolut antara nilai sebenarnya dan nilai perkiraan, sedangkan Root Mean Squared Error (RMSE) adalah akar kuadrat dari MSE. Ini memberikan gambaran tentang besarnya kesalahan dengan satuan yang sama dengan variabel dependen, kedua metric ini memberikan gambaran tentang besarnya kesalahan dalam skala aslinya. Tujuan utama dari dilakukan banyak permodelan adalah untuk mendapatkan nilai MAE, MSE, dan RMSE yang rendah, menandakan tingkat akurasi yang tinggi dalam prediksi harga mobil bekas. Dengan menggunakan kombinasi metrik ini, kita dapat mengevaluasi performa model dengan presisi dan keandalan yang tinggi, yang esensial untuk memberikan kepercayaan kepada pembeli dan penjual dalam pasar otomotif yang dinamis di Arab Saudi.

# %% [markdown]
# # Data Understanding
#
# - Dataset merupakan record dari mobil bekas di Saudi Arabia
# - Atribut terdiri dari Numerikal maupun Kategorikal
# - Setiap baris merepresentasikan spec data dari mobil bekas
#
# **Attributes Information**
#
# | **Attribute** | **Data Type** | **Description** |
# | --- | --- | --- |
# | Type | Object | Type of used car |
# | Region | Object | The region in which the used car was offered for sale |
# | Make | Object | The company name |
# | Gear_Type | Object | Gear type size of used car |
# | Origin | Object | Origin of used car |
# | Options | Object | Options of used car |
# | Year | integer | Manufacturing year |
# | Engine_Size | Float | The engine size of used car |
# | Mileage | integer | Mileage of used car |
# | Negotiable | bool | True if the price is 0, that means it is negotiable |
# | Price | Integer | Used car price |

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\user\Desktop\Purwadhika\capstone P\Capstone 3\data_saudi_used_cars.csv")
df.head()
# Out:
#           Type          Region        Make  Gear_Type       Origin    Options  \
# 0      Corolla            Abha      Toyota     Manual        Saudi   Standard
# 1        Yukon          Riyadh         GMC  Automatic        Saudi       Full
# 2  Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic       Full
# 3       Optima  Hafar Al-Batin         Kia  Automatic        Saudi  Semi Full
# 4           FJ          Riyadh      Toyota  Automatic        Saudi       Full
#
#    Year  Engine_Size  Mileage  Negotiable   Price
# 0  2013          1.4   421000        True       0
# 1  2014          8.0    80000       False  120000
# 2  2015          5.0   140000       False  260000
# 3  2015          2.4   220000       False   42000
# 4  2020          4.0    49000        True       0

# %%
print(df.shape)
# Out:
# (5624, 11)

# %%
df.info
# Out:
# <bound method DataFrame.info of              Type          Region        Make  Gear_Type       Origin  \
# 0         Corolla            Abha      Toyota     Manual        Saudi
# 1           Yukon          Riyadh         GMC  Automatic        Saudi
# 2     Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3          Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 4              FJ          Riyadh      Toyota  Automatic        Saudi
# ...           ...             ...         ...        ...          ...
# 5619      X-Trail          Jeddah      Nissan  Automatic        Saudi
# 5620       Altima          Jeddah      Nissan  Automatic        Saudi
# 5621        Yukon          Dammam         GMC  Automatic        Saudi
# 5622           RX          Dammam       Lexus  Automatic  Gulf Arabic
# 5623           ES          Jeddah       Lexus  Automatic        Other
#
#         Options  Year  Engine_Size  Mileage  Negotiable   Price
# ...

# %% [markdown]
# # Data Preprocessing
#
# Pada tahap ini yang akan dilakukan:
# - Menghapus data duplicate.
# - Drop fitur yang tidak memiliki relevansi terhadap masalah yang sedang dihadapi.
# - Jika terdapat missing value, perlu dilakukan treatment yang sesuai (Drop fitur, imputasi dengan nilai yang sesuai, drop data, etc).
# - Jika terdapat outlier, perlu dilakukan treatment yang sesuai.

# %%
import missingno

# %%
listItem = []
for col in df.columns :
    listItem.append([col, df[col].dtype, df[col].isna().sum(), round((df[col].isna().sum()/len(df[col])) * 100,2),
                    df[col].nunique(), list(df[col].drop_duplicates().sample(2).values)]);

dfDesc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'],
                     data=listItem)
dfDesc
# Out:
#    dataFeatures dataType  null  nullPct  unique            uniqueSample
# 0          Type   object     0      0.0     347            [XJ, Ciocca]
# 1        Region   object     0      0.0      27       [Najran, Al-Ahsa]
# 2          Make   object     0      0.0      58       [Peugeot, Hummer]
# 3     Gear_Type   object     0      0.0       2     [Automatic, Manual]
# 4        Origin   object     0      0.0       4  [Unknown, Gulf Arabic]
# 5       Options   object     0      0.0       3       [Semi Full, Full]
# 6          Year    int64     0      0.0      50            [1993, 1982]
# 7   Engine_Size  float64     0      0.0      71              [3.0, 2.8]
# 8       Mileage    int64     0      0.0    1716        [164000, 111878]
# 9    Negotiable     bool     0      0.0       2           [False, True]
# 10        Price    int64     0      0.0     467             [1, 203000]

# %%
missingno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# pada data set ini tidak terdapat missing value. Pada data set ini terdapat 7 kolom kategorikal, dan 4 kolom numerikal

# %%
duplicate = df[df.duplicated()]
print('total data yang terduplikat:', duplicate.shape[0])
duplicate_rows = df[df.duplicated(keep=False)]
# melihat data yang terduplikat
print('Duplikat data: \n', duplicate_rows)
# Out:
# total data yang terduplikat: 4
# Duplikat data:
#          Type  Region     Make  Gear_Type Origin   Options  Year  Engine_Size  \
# 236   Sonata  Jeddah  Hyundai  Automatic  Saudi  Standard  2020          2.4
# 540      Rio  Riyadh      Kia  Automatic  Saudi  Standard  2016          1.4
# 953      Rio  Riyadh      Kia  Automatic  Saudi  Standard  2016          1.4
# 2012  Tucson  Dammam  Hyundai  Automatic  Saudi  Standard  2016          2.0
# 3631   Camry  Riyadh   Toyota  Automatic  Saudi      Full  2013          2.5
# 4646  Sonata  Jeddah  Hyundai  Automatic  Saudi  Standard  2020          2.4
# 4933  Tucson  Dammam  Hyundai  Automatic  Saudi  Standard  2016          2.0
# 5267   Camry  Riyadh   Toyota  Automatic  Saudi      Full  2013          2.5
#
#       Mileage  Negotiable  Price
# 236       100       False  72910
# 540    270000       False  25000
# 953    270000       False  25000
# 2012   155000       False  45000
# 3631   185000        True      0
# ...

# %%
# menghapus data duplikat
df.drop_duplicates(inplace=True)
print(df.shape)
# Out:
# (5620, 11)

# %% [markdown]
# setelah data duplikat dihapus, total row data menjadi 5620

# %%
df.shape
# Out:
# (5620, 11)

# %%
df.describe()
# Out:
#               Year  Engine_Size       Mileage          Price
# count  5620.000000  5620.000000  5.620000e+03    5620.000000
# mean   2014.100356     3.296299  1.509222e+05   53086.404448
# std       5.793003     1.515253  3.829633e+05   70175.153207
# min    1963.000000     1.000000  1.000000e+02       0.000000
# 25%    2012.000000     2.000000  3.800000e+04       0.000000
# 50%    2016.000000     3.000000  1.030000e+05   36500.000000
# 75%    2018.000000     4.500000  1.960000e+05   73000.000000
# max    2022.000000     9.000000  2.000000e+07  850000.000000

# %%
min_price = df['Price'].min()
max_price = df['Price'].max()
print("Minimum Price:", min_price)
print("Maximum Price:", max_price)
# Out:
# Minimum Price: 0
# Maximum Price: 850000

# %% [markdown]
# Harga mobil 0 tidak relevan dan dapat merusak keakuratan model dalam memprediksi harga mobil bekas. Oleh karena itu, menghapus data ini dapat membantu untuk memastikan kualitas dan keandalan model machine learning.

# %%
zero_price_rows = df[df['Price'] == 0]
zero_price_rows
# Out:
#               Type  Region     Make  Gear_Type       Origin    Options  Year  \
# 0          Corolla    Abha   Toyota     Manual        Saudi   Standard  2013
# 4               FJ  Riyadh   Toyota  Automatic        Saudi       Full  2020
# 9               LS   Aseer    Lexus  Automatic        Saudi       Full  1998
# 14           Hilux   Yanbu   Toyota  Automatic        Saudi       Full  2014
# 15    Land Cruiser   Aseer   Toyota     Manual  Gulf Arabic  Semi Full  1982
# ...            ...     ...      ...        ...          ...        ...   ...
# 5610      Town Car  Jeddah  Lincoln  Automatic        Other       Full  1999
# 5614      Victoria  Makkah     Ford  Automatic        Saudi   Standard  2010
# 5617         Yukon  Jubail      GMC  Automatic        Saudi  Semi Full  2006
# 5620        Altima  Jeddah   Nissan  Automatic        Saudi  Semi Full  2020
# 5623            ES  Jeddah    Lexus  Automatic        Other       Full  2017
#
# ...

# %%
data = df[df['Price'] != 0]
data
# Out:
#              Type          Region        Make  Gear_Type       Origin  \
# 1           Yukon          Riyadh         GMC  Automatic        Saudi
# 2     Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3          Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 5             CX3            Abha       Mazda  Automatic        Saudi
# 6       Cayenne S          Riyadh     Porsche  Automatic        Saudi
# ...           ...             ...         ...        ...          ...
# 5616          CX9          Qassim       Mazda  Automatic        Saudi
# 5618     Suburban          Riyadh         GMC  Automatic        Saudi
# 5619      X-Trail          Jeddah      Nissan  Automatic        Saudi
# 5621        Yukon          Dammam         GMC  Automatic        Saudi
# 5622           RX          Dammam       Lexus  Automatic  Gulf Arabic
#
#         Options  Year  Engine_Size  Mileage  Negotiable   Price
# ...

# %%
# Drop kolom negotiable karena tidak relevan dalam prediksi harga mobil bekas
data.drop('Negotiable', axis=1, inplace=True)
data
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4144\966775154.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('Negotiable', axis=1, inplace=True)
#              Type          Region        Make  Gear_Type       Origin  \
# 1           Yukon          Riyadh         GMC  Automatic        Saudi
# 2     Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3          Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 5             CX3            Abha       Mazda  Automatic        Saudi
# 6       Cayenne S          Riyadh     Porsche  Automatic        Saudi
# ...           ...             ...         ...        ...          ...
# 5616          CX9          Qassim       Mazda  Automatic        Saudi
# ...

# %% [markdown]
# Sebanyak 1796 rows dimana price = 0 tidak akan di include ke dalam data yang akan digunakan, sehingga tersisa 3824 rows data (68% data)

# %%
# Data Correlation

import matplotlib.pyplot as plt
import seaborn as sns

numeric_data = data.select_dtypes(include=['float64', 'int64'])  # Select only numeric columns

plt.figure(figsize=(15, 12))
palette = sns.diverging_palette(20, 220, n=256)
corr = numeric_data.corr(method='pearson')
sns.heatmap(corr, annot=True, fmt='.2f', cmap=palette, square=True, linewidths=.5)
plt.title('Correlation Matrix', size=15, weight='bold')
plt.show()

# %% [markdown]
# dapat dilihat dari correlation matrix yang terbentuk, hanya year yang memiliki korelasi positif yang lemah, sedangkan pada engine size dan mileage tidak menunjukkan adanya korelasi yang signifikan. Namun secara praktiknya atribut-atribut diatas dapat mempengaruhi harga mobil sehingga pada kasus ini tetap dimasukkan dalam permodelan

# %% [markdown]
# # Pengecekan Outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numerical_columns = data.select_dtypes(include='number')

# Plotting boxplots for each numerical column
for column in numerical_columns.columns:
    plt.figure(figsize=(5, 3))
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot for {column}')
    plt.show()

# %%
def find_anomalies(data):
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    limit = iqr*1.5
    print(f'IQR: {iqr}')

    limit_bawah = q1 - limit
    limit_atas = q3 + limit
    print(f'limit_bawah: {limit_bawah}')
    print(f'limit_atas: {limit_atas}')

# %%
find_anomalies(data['Year'])
# Out:
# IQR: 5.0
# limit_bawah: 2005.5
# limit_atas: 2025.5

# %%
find_anomalies(data['Engine_Size'])
# Out:
# IQR: 2.0
# limit_bawah: -1.0
# limit_atas: 7.0

# %%
engine_outlier = data[data['Engine_Size'] > 7]
engine_outlier
# Out:
#                 Type     Region        Make  Gear_Type       Origin  \
# 1              Yukon     Riyadh         GMC  Automatic        Saudi
# 59             Camry       Taef      Toyota  Automatic        Saudi
# 600                G     Riyadh    Mercedes  Automatic        Saudi
# 650                E     Jeddah    Mercedes     Manual        Other
# 750               LX       Taef       Lexus  Automatic  Gulf Arabic
# 883         Cadillac     Riyadh     Classic  Automatic        Saudi
# 963            D-MAX       Abha       Isuzu     Manual        Saudi
# 1057            F150     Riyadh        Ford  Automatic        Saudi
# 1166    Land Cruiser       Hail      Toyota  Automatic        Saudi
# 1199           Other     Qassim       Other     Manual        Other
# 1227            Dyna     Riyadh       Isuzu     Manual        Saudi
# 1400           Yukon     Makkah         GMC  Automatic        Saudi
# 1547         Marquis     Riyadh        Ford  Automatic        Other
# ...

# %%
engine_count= len(engine_outlier)
print(engine_count)
# Out:
# 30

# %% [markdown]
# pengecekan salah satu data sebagai sampel, dimana toyota camry tahun 2001 memiliki engine size 9.0.Berdasarkan refrensi https://en.wikipedia.org/wiki/Toyota_Camry_(XV20) menunjukkan kisaran engine size seharusnya adalah 2.2 - 3.0. dapat diasumsikan bahwa outlier yang muncul akibat dari kesalahan input sehingga harus di hapus agar model tidak terjadi distorsi

# %%
data = data[data['Engine_Size'] <= 7]
data
# Out:
#              Type          Region        Make  Gear_Type       Origin  \
# 2     Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3          Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 5             CX3            Abha       Mazda  Automatic        Saudi
# 6       Cayenne S          Riyadh     Porsche  Automatic        Saudi
# 7          Sonata          Riyadh     Hyundai  Automatic        Saudi
# ...           ...             ...         ...        ...          ...
# 5616          CX9          Qassim       Mazda  Automatic        Saudi
# 5618     Suburban          Riyadh         GMC  Automatic        Saudi
# 5619      X-Trail          Jeddah      Nissan  Automatic        Saudi
# 5621        Yukon          Dammam         GMC  Automatic        Saudi
# 5622           RX          Dammam       Lexus  Automatic  Gulf Arabic
#
#         Options  Year  Engine_Size  Mileage   Price
# 2          Full  2015          5.0   140000  260000
# ...

# %%
find_anomalies(data['Mileage'])
# Out:
# IQR: 134430.0
# limit_bawah: -153131.5
# limit_atas: 384588.5

# %%
mileage_outlier = data[data['Mileage'] > 700000]
mileage_outlier
# Out:
#               Type  Region        Make  Gear_Type       Origin    Options  \
# 110          Optra  Riyadh   Chevrolet  Automatic        Saudi   Standard
# 333    Range Rover  Jeddah  Land Rover  Automatic        Saudi       Full
# 453          Azera  Riyadh     Hyundai  Automatic        Saudi  Semi Full
# 572          Camry   Yanbu      Toyota  Automatic        Other       Full
# 578         Copper  Qassim        MINI     Manual        Saudi       Full
# 915     Pathfinder  Riyadh      Nissan  Automatic        Saudi   Standard
# 1334         Prado  Makkah      Toyota     Manual        Saudi  Semi Full
# 1412   Trailblazer  Jeddah   Chevrolet  Automatic        Other       Full
# 1957         Hilux  Jeddah      Toyota     Manual        Saudi       Full
# 2115        Optima  Riyadh         Kia  Automatic        Saudi       Full
# 2427       Corolla  Riyadh      Toyota     Manual        Saudi   Standard
# 2493        Innova  Riyadh      Toyota  Automatic  Gulf Arabic   Standard
# ...

# %%
mileage_count= len(engine_outlier)
print(mileage_count)
# Out:
# 30

# %% [markdown]
# berdasarkan boxplot diatas limit bawah berada di -153131.5 dan limit atas di 384588.5. Mileage mobil ada yang mencapai hingga 20000000 km, hal ini mungkin sangat jarang terjadi atau bisa dianggap sebagai abnormality sehingga pada kolom mileage dibuat pembatasan max 700000 untuk mencegah distorsi pada model. mileage >700000 berjumlah total 30 dan akan di keluarkan agar tidak merusak model

# %%
data = data[data['Mileage'] < 700000]
data
# Out:
#              Type          Region        Make  Gear_Type       Origin  \
# 2     Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3          Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 5             CX3            Abha       Mazda  Automatic        Saudi
# 6       Cayenne S          Riyadh     Porsche  Automatic        Saudi
# 7          Sonata          Riyadh     Hyundai  Automatic        Saudi
# ...           ...             ...         ...        ...          ...
# 5616          CX9          Qassim       Mazda  Automatic        Saudi
# 5618     Suburban          Riyadh         GMC  Automatic        Saudi
# 5619      X-Trail          Jeddah      Nissan  Automatic        Saudi
# 5621        Yukon          Dammam         GMC  Automatic        Saudi
# 5622           RX          Dammam       Lexus  Automatic  Gulf Arabic
#
#         Options  Year  Engine_Size  Mileage   Price
# 2          Full  2015          5.0   140000  260000
# ...

# %%
find_anomalies(data['Price'])
# Out:
# IQR: 59000.0
# limit_bawah: -53500.0
# limit_atas: 182500.0

# %%
Price_outlier = data[data['Price'] > 500000]
Price_outlier
# Out:
#              Type  Region         Make  Gear_Type       Origin Options  Year  \
# 2120        Ghost  Dammam  Rolls-Royce  Automatic        Saudi    Full  2016
# 2504  Range Rover  Riyadh   Land Rover  Automatic        Saudi    Full  2020
# 2862  Range Rover  Riyadh   Land Rover  Automatic        Saudi    Full  2019
# 3105  Range Rover  Riyadh   Land Rover  Automatic  Gulf Arabic    Full  2020
# 3513     Bentayga  Dammam      Bentley  Automatic        Saudi    Full  2019
# 3561  Range Rover  Riyadh   Land Rover  Automatic        Saudi    Full  2020
# 4273            S  Dammam     Mercedes  Automatic  Gulf Arabic    Full  2021
# 4653  Range Rover  Riyadh   Land Rover  Automatic        Other    Full  2019
# 4684            G  Riyadh     Mercedes  Automatic        Other    Full  2019
#
#       Engine_Size  Mileage   Price
# 2120          6.0    40000  620000
# 2504          3.0    11500  510000
# 2862          5.6    36000  520000
# 3105          5.0    36000  540000
# ...

# %%
Price_outlier1 = data[data['Price'] < 2000]
Price_outlier1
# Out:
#            Type          Region        Make  Gear_Type       Origin  \
# 46      Elantra            Abha     Hyundai  Automatic        Saudi
# 65       Malibu            Arar   Chevrolet  Automatic        Saudi
# 356      Wingle          Jeddah  Great Wall     Manual        Saudi
# 396          K5           Aseer         Kia  Automatic        Saudi
# 423     Elantra          Riyadh     Hyundai  Automatic        Saudi
# 496       Camry  Hafar Al-Batin      Toyota  Automatic        Saudi
# 596      Sonata          Jeddah     Hyundai  Automatic        Saudi
# 789         CX5          Khobar       Mazda  Automatic        Saudi
# 907      Sentra          Jeddah      Nissan  Automatic        Saudi
# 1423    Corolla          Riyadh      Toyota  Automatic  Gulf Arabic
# 1534      Yukon          Jeddah         GMC  Automatic        Saudi
# 1666      Camry            Taef      Toyota  Automatic        Saudi
# 1715       Edge          Jeddah        Ford  Automatic        Saudi
# ...

# %% [markdown]
# pada price dimana dibawah 2000 riyal terdapat 46 jumlah mobil, beberapa jenis mobil dibawah 2000 riyal bahkan termasuk mobil tahun tinggi, dimana ini hal yang tidak lazim ditemukan bahkan ada mobil dengan harga 1 riyal. pada kasus ini harga mobil di bawah 2000 riyal akan dikeluarkan sehingga tidak mengganggu model

# %% [markdown]
# pada Price dimana harga di atas 500000 riyal berjumlah 9, dimana pada kasus ini akan dihapus agar abnormality harga tidak mengganggu model dalam melakukan prediksi

# %%
df_for_model = data[data['Price'] < 500000]

# %%
df_for_model = data[data['Price'] > 2000]
df_for_model
# Out:
#              Type          Region        Make  Gear_Type       Origin  \
# 2     Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic
# 3          Optima  Hafar Al-Batin         Kia  Automatic        Saudi
# 5             CX3            Abha       Mazda  Automatic        Saudi
# 6       Cayenne S          Riyadh     Porsche  Automatic        Saudi
# 7          Sonata          Riyadh     Hyundai  Automatic        Saudi
# ...           ...             ...         ...        ...          ...
# 5616          CX9          Qassim       Mazda  Automatic        Saudi
# 5618     Suburban          Riyadh         GMC  Automatic        Saudi
# 5619      X-Trail          Jeddah      Nissan  Automatic        Saudi
# 5621        Yukon          Dammam         GMC  Automatic        Saudi
# 5622           RX          Dammam       Lexus  Automatic  Gulf Arabic
#
#         Options  Year  Engine_Size  Mileage   Price
# 2          Full  2015          5.0   140000  260000
# ...

# %% [markdown]
# setelah dilakukan Data Cleaning terdapat 3725 jumlah data yang akan dipergunakan dalam membuat model machine learning

# %%
df_for_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3725 entries, 2 to 5622
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Type         3725 non-null   object
#  1   Region       3725 non-null   object
#  2   Make         3725 non-null   object
#  3   Gear_Type    3725 non-null   object
#  4   Origin       3725 non-null   object
#  5   Options      3725 non-null   object
#  6   Year         3725 non-null   int64
#  7   Engine_Size  3725 non-null   float64
#  8   Mileage      3725 non-null   int64
#  9   Price        3725 non-null   int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 320.1+ KB

# %%
# Import library untuk modeling

from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, GridSearchCV, KFold

import category_encoders as ce
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.compose import TransformedTargetRegressor

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %% [markdown]
# # Encoding

# %%
ordinal_mapping = [{
    'col' : 'Options',
    'mapping' : {None:0, 'Standard':1, 'Semi Full':2, 'Full':3}
}]

ordinal_encoder = ce.OrdinalEncoder(cols = 'Options', mapping = ordinal_mapping)

# %%
transformer = ColumnTransformer([
    ('One Hot', OneHotEncoder(drop='first', handle_unknown='ignore'), ['Gear_Type']),
    ('Ordinal', ordinal_encoder, ['Options']),
    ('Binary', ce.BinaryEncoder(), ['Make', 'Type', 'Region', 'Origin'])
    ], remainder = 'passthrough')

# %% [markdown]
# # Modelling

# %% [markdown]
# Splitting Dataset

# %%
X = df_for_model.drop(columns = 'Price', axis = 1)
y = df_for_model['Price']

# %%
# Split data training dan test dengan proporsi 70:30

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size = 0.3,
    random_state = 42)

# %% [markdown]
# **Memilih Model Terbaik**
#
# Pada tahapan ini akan dilakukan permodelan dengan menggunakan base model dan ensembel model.
#
# Base model yang digunakan adalah Linear Regression, KNN Regressor, dan Decision Tree Regressor.<br>
# Sedangkan Model Ensemble yang digunakan adalah Random Forest, dan XGB Regressor.

# %%
# Define Algoritma
lr = LinearRegression()
knn = KNeighborsRegressor()
dt = DecisionTreeRegressor(random_state = 42)
rf = RandomForestRegressor(random_state = 42)
xgb = XGBRegressor(random_state = 42)

log_lr = TransformedTargetRegressor(lr, func = np.log, inverse_func = np.exp)
log_knn = TransformedTargetRegressor(knn, func = np.log, inverse_func = np.exp)
log_dt = TransformedTargetRegressor(dt, func = np.log, inverse_func = np.exp)
log_rf = TransformedTargetRegressor(rf, func = np.log, inverse_func = np.exp)
log_xgb = TransformedTargetRegressor(xgb, func = np.log, inverse_func = np.exp)

# Scaling data manggunakan standar scaler
scaler = StandardScaler()

# Kandidat Algoritma
models = [log_lr, log_knn, log_dt, log_rf, log_xgb]

score_r2 = []

score_rmse = []
nilai_mean_rmse = []
nilai_std_rmse = []

score_mae = []
nilai_mean_mae = []
nilai_std_mae = []

score_mape = []
nilai_mean_mape = []
nilai_std_mape = []

# Mencari model terbaik berdasrakan tiap metric
for i in models:

    crossval = KFold(n_splits = 5, shuffle = True, random_state = 42)

    estimator = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', i)
    ])

    #RMSE
    model_cv_rmse = cross_val_score(
        estimator,
        X_train,
        y_train,
        cv = crossval,
        scoring = 'neg_root_mean_squared_error',
        error_score = 'raise')
    
    print(model_cv_rmse, i)

    score_rmse.append(model_cv_rmse)
    nilai_mean_rmse.append(model_cv_rmse.mean())
    nilai_std_rmse.append(model_cv_rmse.std())

    #MAE
    model_cv_mae = cross_val_score(
        estimator,
        X_train,
        y_train,
        cv = crossval,
        scoring = 'neg_mean_absolute_error',
        error_score = 'raise')
    
    print(model_cv_mae, i)

    score_mae.append(model_cv_mae)
    nilai_mean_mae.append(model_cv_mae.mean())
    nilai_std_mae.append(model_cv_mae.std())

    #MAPE
    model_cv_mape = cross_val_score(
        estimator,
        X_train,
        y_train,
        cv = crossval,
        scoring = 'neg_mean_absolute_percentage_error',
        error_score = 'raise')
    
    print(model_cv_mape, i)

    score_mape.append(model_cv_mape)
    nilai_mean_mape.append(model_cv_mape.mean())
    nilai_std_mape.append(model_cv_mape.std())

    #R-Square
    r2_cv = cross_val_score(
        estimator,
        X_train,
        y_train,
        cv = crossval,
        scoring = 'r2',
        error_score = 'raise')
    
    print(r2_cv, i)

    score_r2.append(r2_cv)
# Out:
# [-57821.37722504 -49577.88853385 -52047.58699568 -44112.65315978
#  -57407.81681748] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-28778.67540164 -27059.9565031  -27643.30869285 -23711.39524283
#  -28910.50231054] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-0.36535543 -0.75676981 -0.50393438 -0.60904038 -0.43782602] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [0.50069384 0.5770019  0.5689643  0.56299927 0.45470817] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-56658.72045313 -49690.76253421 -49997.08614806 -39994.93062395
#  -54478.57350551] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
# ...

# %%
# Evaluasi hasil dari 5 kandidat algoritma yang digunakan

pd.DataFrame({
    'Model' : ['Linear Regression','KNN Regressor', 'DecisionTree Regressor', 'RandomForest Regressor','XGBoost Regressor'],
    'mean_RMSE' : nilai_mean_rmse,
    'std_RMSE' : nilai_std_rmse,
    'mean_MAE' : nilai_mean_mae,
    'std_mae' : nilai_std_mae,
    'mean_MAPE' : nilai_mean_mape,
    'std_MAPE' : nilai_std_mape
})
# Out:
#                     Model     mean_RMSE     std_RMSE      mean_MAE  \
# 0       Linear Regression -52193.464546  5119.080025 -27220.767630
# 1           KNN Regressor -50164.014653  5735.132504 -26657.786591
# 2  DecisionTree Regressor -51772.151352  7579.083514 -25503.646117
# 3  RandomForest Regressor -39739.841050  4459.030494 -18885.471977
# 4       XGBoost Regressor -36675.619716  5297.609987 -18498.433091
#
#        std_mae  mean_MAPE  std_MAPE
# 0  1886.922131  -0.534585  0.137004
# 1  1718.901737  -0.590939  0.144131
# 2  1896.016704  -0.578209  0.207097
# 3  1337.776704  -0.423919  0.153590
# 4  1826.273864  -0.418216  0.162240

# %% [markdown]
# Hasil evaluasi model regresi menunjukkan bahwa Random Forest Regressor dan XGBoost Regressor memiliki performa yang lebih baik dibandingkan dengan model lainnya dalam dataset ini. Kedua model tersebut menunjukkan kesalahan prediksi yang lebih rendah (ditandai dengan RMSE dan MAE rata-rata yang lebih kecil) dan konsistensi yang lebih tinggi dalam prediksi (dengan std yang lebih rendah). Secara khusus, XGBoost Regressor menonjol dengan hasil yang paling baik dalam semua metrik evaluasi, menunjukkan bahwa model ini paling cocok untuk tugas regresi pada dataset tersebut. Meskipun demikian, keputusan akhir dalam memilih model terbaik harus didasarkan pada pertimbangan lebih lanjut seperti interpretasi model, kompleksitas, dan kebutuhan khusus dari kasus penggunaan yang bersangkutan. Dengan demikian, dalam kasus ini, Random Forest Regressor dan XGBoost Regressor dapat dianggap sebagai pilihan utama untuk prediksi regresi yang akurat.

# %% [markdown]
# **Predict to Test Set with The Benchmark Model**
#
# Prediksi pada test set dengan menggunakan model XGBoost dan Random Forest

# %%
# Benchmark 2 Model

models = {
    'XGB' : XGBRegressor(random_state = 42),
    'RandomForest' : RandomForestRegressor(random_state = 42)
}

score_rmse = []
score_mae = []
score_mape = []

# Prediksi pada set test
for i in models:

    model = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', models[i])
    ])

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    score_rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    score_mae.append(mean_absolute_error(y_test, y_pred))
    score_mape.append(mean_absolute_percentage_error(y_test, y_pred))

score_before_tuning = pd.DataFrame({'RMSE': score_rmse, 'MAE': score_mae, 'MAPE': score_mape}, index=models.keys())
score_before_tuning
# Out:
#                       RMSE           MAE      MAPE
# XGB           32319.975434  18567.359224  0.447065
# RandomForest  32802.323504  17565.686843  0.461202

# %% [markdown]
# Dari hasil ini, terlihat bahwa XGBoost Regressor memiliki RMSE yang sedikit lebih rendah daripada Random Forest Regressor, menunjukkan bahwa XGBoost mungkin sedikit lebih baik dalam membuat prediksi yang lebih dekat dengan nilai sebenarnya. Namun, Random Forest memiliki MAE yang lebih rendah, menunjukkan bahwa secara rata-rata, kesalahan absolutnya lebih kecil. MAPE untuk kedua model relatif mirip, tetapi lebih rendah untuk XGBoost, menandakan bahwa secara rata-rata, kesalahan persentase prediksinya lebih kecil. Dengan demikian, XGBoost mungkin merupakan pilihan yang sedikit lebih baik berdasarkan metrik evaluasi yang digunakan. Namun, untuk memastikan pilihan model terbaik, penyetelan lebih lanjut dan evaluasi yang lebih mendalam mungkin diperlukan.

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# XGBoost Regressor menunjukkan performa yang sedikit lebih baik secara keseluruhan, sehingga pada tahap ini akan dilakukan tuning untuk menentukan parameter terbaik untuk XGBoost, Acuan untuk melakukan tuning dengan model XGBoost mengacu pada [XGBoost Tuning ](https://xgboost.readthedocs.io/en/latest/parameter.html#general-parameters)

# %%
# Kedalaman pohon
max_depth = list(np.arange(1,11))

# Learning rate
learning_rate = list(np.arange(1,100)/100)

# Jumlah pohon
n_estimators = list(np.arange(100,201))

# Jumlah baris tiap pohon (% dari total baris train set)
subsample = list(np.arange(2,10)/10)

# Gamma (min_impurity_decrease)
gamma = list(np.arange(1,11))

# Jumlah feature yang digunakan untuk tiap pohon (% dari total kolom train set)
colsample_bytree = list(np.arange(1,10)/10)

# Alpha (Regularization)
reg_alpha = list(np.logspace(-3, 1, 10))

# Hyperparamater space XGBoost
hyperparam_space_xgb = {
    'model__max_depth': max_depth, 
    'model__learning_rate': learning_rate,
    'model__n_estimators': n_estimators,
    'model__subsample': subsample,
    'model__gamma': gamma,
    'model__colsample_bytree': colsample_bytree,
    'model__reg_alpha': reg_alpha
}

# %%
# Benchmark model dengan hyperparameter tuning
xgb = XGBRegressor(random_state=42, verbosity=0)

# Membuat algorithm chains
estimator_xgb = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', xgb)
        ])

crossval = KFold(n_splits=5, shuffle=True, random_state=0)

# Hyperparameter tuning
random_xgb = RandomizedSearchCV(
    estimator_xgb, 
    param_distributions = hyperparam_space_xgb,
    n_iter = 50,
    cv = crossval, 
    scoring = ['neg_root_mean_squared_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error'], 
    n_jobs = -1,
    refit = 'neg_root_mean_squared_error',
    random_state = 42
)

# %%
# Fitting data training untuk mencari parameter terbaik
random_xgb.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=0, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('One '
#                                                                                'Hot',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              handle_unknown='ignore'),
#                                                                                ['Gear_Type']),
#                                                                               ('Ordinal',
#                                                                                OrdinalEncoder(cols='Options',
# ...

# %%
# Melihat hasil tuning dalam bentuk dataframe. Diurutkan berdasarkan RMSE, MAE & MAPE
pd.DataFrame(random_xgb.cv_results_).sort_values(by=['rank_test_neg_root_mean_squared_error', 'rank_test_neg_mean_absolute_error', 'rank_test_neg_mean_absolute_percentage_error']).head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9        0.353128      0.017064         0.046170    6.466168e-03
# 26       0.432536      0.015714         0.042355    8.341755e-03
# 18       0.682568      0.023845         0.043739    6.248474e-03
# 39       1.162497      0.035107         0.056926    9.923995e-03
# 13       0.513384      0.007432         0.031242    7.168434e-07
#
#    param_model__subsample param_model__reg_alpha param_model__n_estimators  \
# 9                     0.9               0.059948                       105
# 26                    0.4                1.29155                       100
# 18                    0.2               0.059948                       193
# 39                    0.6               0.059948                       141
# 13                    0.4               0.007743                       158
#
#    param_model__max_depth param_model__learning_rate param_model__gamma  ...  \
# ...

# %%
# Cek skor dan params terbaik
print('XGBoost')
print('Best_score:', random_xgb.best_score_)
print('Best_params:', random_xgb.best_params_)
# Out:
# XGBoost
# Best_score: -35796.29184164201
# Best_params: {'model__subsample': 0.9, 'model__reg_alpha': 0.05994842503189409, 'model__n_estimators': 105, 'model__max_depth': 5, 'model__learning_rate': 0.38, 'model__gamma': 3, 'model__colsample_bytree': 0.7}

# %% [markdown]
# **Predict to Test Set with The Tuned Model**
#
# Melakukan prediksi pada set test dengan menggunakan model XGBoost dan Hyperparameter terpilih.

# %%
# Model XGBoost
model = {'XGB' : XGBRegressor(random_state = 42)}

# Define Model terhadap estimator terbaik
xgb_tuning = random_xgb.best_estimator_

# Fitting Model
xgb_tuning.fit(X_train, y_train)

# Predict test set
y_pred_xgb_tuning = xgb_tuning.predict(X_test)

# Simpan nilai metrics RMSE, MAE & MAPE setelah tuning
rmse_xgb_tuning = np.sqrt(mean_squared_error(y_test, y_pred_xgb_tuning))
mae_xgb_tuning = mean_absolute_error(y_test, y_pred_xgb_tuning)
mape_xgb_tuning = mean_absolute_percentage_error(y_test, y_pred_xgb_tuning)

score_after_tuning = pd.DataFrame({'RMSE' : rmse_xgb_tuning, 'MAE' : mae_xgb_tuning, 'MAPE' : mape_xgb_tuning}, index = model.keys())
score_after_tuning
# Out:
#              RMSE           MAE     MAPE
# XGB  32158.847834  19000.649055  0.48485

# %% [markdown]
# **Performance Comparison**
#
# Perbandingan antara model XGBoost sebelum dan sesudah dilakukannya Hyperparameter Tuning.

# %%
# Sebelum hyperparameter tuning
pd.DataFrame(score_before_tuning.loc['XGB']).T
# Out:
#              RMSE           MAE      MAPE
# XGB  32319.975434  18567.359224  0.447065

# %%
# Setelah hyperparameter tuning
score_after_tuning
# Out:
#              RMSE           MAE     MAPE
# XGB  32158.847834  19000.649055  0.48485

# %% [markdown]
# Dari nilai-nilai ini, dapat dilihat bahwa terjadi perubahan dalam kinerja model setelah penyetelan hyperparameter. Meskipun RMSE mengalami penurunan yang kecil, terjadi peningkatan yang signifikan pada nilai MAE dan MAPE, menandakan bahwa penyetelan hyperparameter mungkin tidak menghasilkan peningkatan yang signifikan dalam akurasi dan konsistensi prediksi model. Evaluasi ini memberikan gambaran tentang efektivitas penyetelan hyperparameter dalam meningkatkan kinerja model XGBoost Regressor.

# %%
plt.figure(figsize = (15,8))
plot = sns.scatterplot(x = y_test, y = y_pred_xgb_tuning).set(title = 'Actual vs Prediction Price',
                                                    xlabel = 'Actual Price',
                                                    ylabel = 'Prediction Price')

# %% [markdown]
# Grafik menunjukkan korelasi positif antara kedua harga, dengan beberapa penyebaran data yang mengindikasikan variasi dalam akurasi prediksi. Model cenderung lebih akurat pada harga yang rendah daripada pada harga yang tinggi, dan terdapat beberapa nilai yang sangat berbeda dari kebanyakan (outliers) yang bisa menandakan kesalahan prediksi besar atau nilai aktual yang tidak biasa. Grafik ini berguna untuk mengevaluasi dan potensial memperbaiki model prediktif yang digunakan.

# %% [markdown]
# **Feature Importance**
#
# Untuk mengetahui fitur yang dapat mempengaruhi `Price` kita akan melakukan analisa melalui feature importance.

# %%
feature_imp = pd.Series(xgb_tuning['model'].feature_importances_, transformer.get_feature_names_out()).sort_values(ascending = False).head()
feature_imp.plot(kind='barh', title='Feature Importances');

# %% [markdown]
# # Kesimpulan
# Setelah serangkaian proses analisa dan permodelan, maka dapat kita simpulkan:
#
# 1. Beberapa jenis permodelan telah dilakukan, permodelan terbaik (Best Model) adalah dengan menggunakan XGBoost tanpa hyperparameter tuning, didapatkan:
# RMSE: 32319.97
# MAE: 18567.35
# MAPE: 0.447
# Pada model ini dapat melakukan prediksi harga dengan limitasi antara 2000 sampai dengan 500000, diluar rentang harga ini prediksi tidak akan akurat. Secara keseluruhan, interpretasi ini menunjukkan bahwa model XGBoost belum memuaskan dalam memodelkan data dengan akurat. Meskipun memiliki performa yang relatif baik dalam memprediksi, masih diperlukan penyetelan lebih lanjut atau pengoptimalan model untuk meningkatkan akurasi prediksi dan mengurangi kesalahan.
#
# 2. Fitur "Engine_Size" sebagai yang fitur terpenting, menunjukkan peran penting ukuran mesin dalam prediksi, diikuti dengan "Year" (tahun produksi) menjadi fitur kedua terpenting, menandakan tahun kendaraan juga signifikan mempengaruhi prediksi. Sementara itu, fitur lain mungkin menunjukkan keberadaan atau ketiadaan kategori tertentu, seperti merek atau tipe mobil, dengan pengaruh yang relatif lebih rendah.
#
# 3. Evaluasi performa model prediktif, pada kasus ini dalam konteks prediksi harga, menunjukkan bahwa model cenderung memberikan prediksi yang lebih akurat pada harga yang rendah daripada pada harga yang tinggi, sementara adanya outlier dapat mengindikasikan terjadinya kesalahan prediksi besar atau keberadaan nilai aktual yang tidak biasa.

# %% [markdown]
# # Rekomendasi

# %% [markdown]
# Rekomendasi yang dapat dilakukan untuk meng improve model Machine Learning yang telah dibuat:
#
# 1. Rekomendasi yang pertama adalah penambahan fitur-fitur tambahan yang dapat meningkatkan akurasi prediksi, seperti kondisi fisik dan mesin mobil yang dapat dikelompokkan dalam kategori A (baik), B (cukup), C (kurang), dan D (buruk). Selain itu, menambahkan fitur-fitur seperti status legalitas mobil juga dapat membantu memperbaiki model. Penambahan fitur-fitur baru yang relevan akan membantu model dalam mengidentifikasi pola-pola yang lebih kompleks dan meningkatkan keakuratan dalam memprediksi harga mobil.
#
# 2.  Rekomendasi kedua adalah memperbaiki kualitas data dengan mengumpulkan lebih banyak data atau melakukan perbaikan terhadap data yang ada. Hal ini termasuk mengatasi bias dalam data seperti harga mobil bekas yang berada di bawah satu, yang dapat menyebabkan distorsi pada model. Dengan melakukan evaluasi berkelanjutan terhadap performa model, diharapkan akan terjadi peningkatan yang signifikan dalam akurasi prediksi, yang pada gilirannya akan mendukung pengambilan keputusan yang lebih baik dan efisien dalam pemodelan harga mobil. Dengan menggabungkan kedua rekomendasi ini, model dapat ditingkatkan secara substansial untuk memberikan prediksi harga mobil yang lebih akurat dan dapat diandalkan.

# %%
# Save model
import pickle

estimator = Pipeline([('preprocess', transformer), ('model', XGBRegressor())])
estimator.fit(X_train, y_train)

pickle.dump(estimator, open('model_saudi_arabia_UC_XGB.sav', 'wb'))

# %%
# Load model
filename = 'model_saudi_arabia_UC_XGB.sav'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
np.sqrt(mean_squared_error(y_test, loaded_model.predict(X_test)))
# Out:
# 32319.97543415882
